# %%
from facebook_business.api import FacebookAdsApi
from facebook_business import FacebookSession
from facebook_business.adobjects.user import User
from facebook_business.adobjects.campaign import Campaign
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.adpreview import AdPreview
# from facebookads.adobjects.adset import AdSet
# from facebookads.adobjects.adimage import AdImage
# from facebookads.adobjects.adspixel import AdsPixel
from facebook_business.adobjects.adcreative import AdCreative
from facebook_business.adobjects.ad import Ad
# from facebookads.adobjects.targeting import Targeting
import json
import os
import unicodedata

# %%
my_app_id = "2280157165384459"
my_app_secret = "5caa8b5c49cf78f2285f9921b51baf98"
my_access_token_1 = "EAAgZAynXf8wsBAECSf1NPj4ZAajFgeagcXWj5cZAa82MkOIGFOqzNe4pkhX5ZCzhBeNwO2gU32qvOamvu1QXCeCjWnIKoXb2ry9guneMZB49789ZBPSClGcRlZBZASmIJfRKYHtV7VGJygUS5sowDOGzP2n25OW94dUZD"

session1 = FacebookSession(
    my_app_id,
    my_app_secret,
    my_access_token_1
)

api1 = FacebookAdsApi(session1)
# 2039741129633793
print(api1)

FacebookAdsApi.set_default_api(api1)
me = User(fbid='me', api=api1)
my_accounts = list(me.get_ad_accounts())

print(my_accounts)

my_account = my_accounts[0]

my_account_id = 'act_2039741129633793'

account = AdAccount(my_account_id)

insights = account.get_insights(fields=[
    'impressions',
    'ad_id',
    'clicks',
    'spend',
    'unique_clicks',
    'unique_actions',
    'cpm',
    'cpc',
    'adset_name',
    'ad_name',
    'campaign_name',
    'actions',
    'cpp',
    'ctr',
    'reach',
    'unique_clicks',
    'unique_ctr',
    'date_start',
    'date_stop'
], params={
    'level': 'ad',
    'date_presets': 'last_month',
})
# Out:
# <facebook_business.api.FacebookAdsApi object at 0x10cca0b70>
# [<AdAccount> {
#     "account_id": "11797979",
#     "id": "act_11797979"
# }, <AdAccount> {
#     "account_id": "56472649",
#     "id": "act_56472649"
# }, <AdAccount> {
#     "account_id": "108407819300052",
#     "id": "act_108407819300052"
# }, <AdAccount> {
#     "account_id": "743280435812784",
#     "id": "act_743280435812784"
# }, <AdAccount> {
#     "account_id": "113812349144053",
#     "id": "act_113812349144053"
# }, <AdAccount> {
#     "account_id": "1648097352139643",
#     "id": "act_1648097352139643"
# }, <AdAccount> {
#     "account_id": "1921492931512222",
#     "id": "act_1921492931512222"
# }, <AdAccount> {
#     "account_id": "2039741129633793",
#     "id": "act_2039741129633793"
# }, <AdAccount> {
#     "account_id": "2007692376220507",
#     "id": "act_2007692376220507"
# }]

# %%
import datetime
yesterdaybad = datetime.datetime.now() - datetime.timedelta(days=1)
yesterdayslash = yesterdaybad.strftime('%m/%d/%Y')
yesterdaybad.strftime('%m-%d-%Y')
# Out:
# '02-18-2019'

# %%
import pandas as pd
ad_insights = []
for ad in insights:
    if 'cpc' in ad:
        cool_ad = {
            "ad_id": ad['ad_id'],
            "ad_name": ad['ad_name'],
            "adset_name": ad['adset_name'],
            "campaign_name": ad['campaign_name'],
            "clicks": ad['clicks'],
            "spend": ad['spend'],
            "cpc": ad['cpc'],
            "cpm": ad['cpm'],
            "date_start": ad['date_start'],
            "date_stop": ad['date_stop'],
            'reach': ad['reach'],
            'impressions': ad['impressions'] 
        }
        try:
            actions = ad['unique_actions']
            cart_adds = list(filter(lambda action: action['action_type'] == 'offsite_conversion.fb_pixel_add_to_cart', actions))
            checkouts = list(filter(lambda action: action['action_type'] == 'offsite_conversion.fb_pixel_initiate_checkout', actions))
            view_contents = list(filter(lambda action: action['action_type'] == 'offsite_conversion.fb_pixel_view_content', actions))
            purchases = list(filter(lambda action: action['action_type'] == 'offsite_conversion.fb_pixel_purchase', actions))
            cool_ad['cart_adds'] = 0 
            cool_ad['checkouts'] = 0
            cool_ad['view_contents'] = 0
            cool_ad['purchases'] = 0
            if len(cart_adds) != 0: cool_ad['card_adds'] = int(cart_adds[0]['value'])
            if len(checkouts) != 0: cool_ad['checkouts'] = int(checkouts[0]['value'])
            if len(view_contents) != 0: cool_ad['view_contents'] = int(view_contents[0]['value'])
            if len(purchases) != 0: cool_ad['purchases'] = int(purchases[0]['value'])
            ad_insights.append(cool_ad)
        except:
            print('ADDDDD')
            print(ad)
    
ad_insights_df = pd.DataFrame(ad_insights)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-90e0b0c3d2a1> in <module>()
#      17             'impressions': ad['impressions']
#      18         }
# ---> 19         actions = ad['unique_actions']
#      20         cart_adds = list(filter(lambda action: action['action_type'] == 'offsite_conversion.fb_pixel_add_to_cart', actions))
#      21         checkouts = list(filter(lambda action: action['action_type'] == 'offsite_conversion.fb_pixel_initiate_checkout', actions))
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/adobjects/abstractobject.py in __getitem__(self, key)
#      46
#      47     def __getitem__(self, key):
# ---> 48         return self._data[str(key)]
#      49
#      50     def __setitem__(self, key, value):
#
# KeyError: 'unique_actions'

# %%
len(ad_insights)

# %%
ad_insights_df = pd.DataFrame(ad_insights)

# %%
len(ad_insights_df)

# %%
ad_insights_df.card_adds.value_counts()

# %% [markdown]
# # len(insights)

# %%
creatives = account.get_ad_creatives(fields=[
    'image_url',
    'title',
    'status',
    "url_tags"
], params={
    'level': 'ad',
    # 'time_range': {'since' : '2017-11-07','until': '2017-11-08'},
})
# Out:
# ---------------------------------------------------------------------------
# FacebookRequestError                      Traceback (most recent call last)
# <ipython-input-104-2e687aca6c6a> in <module>()
#       5     "url_tags"
#       6 ], params={
# ----> 7     'level': 'ad',
#       8     # 'time_range': {'since' : '2017-11-07','until': '2017-11-08'},
#       9 })
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/adobjects/adaccount.py in get_ad_creatives(self, fields, params, batch, success, failure, pending)
#     490         else:
#     491             self.assure_call()
# --> 492             return request.execute()
#     493
#     494     def create_ad_creative(self, fields=None, params=None, batch=None, success=None, failure=None, pending=False):
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in execute(self)
#     661                 endpoint=self._endpoint,
#     662             )
# --> 663             cursor.load_next_page()
#     664             return cursor
#     665         if self._fields:
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in load_next_page(self)
#     824             'GET',
#     825             self._path,
# --> 826             params=self.params,
#     827         ).json()
#     828
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in call(self, method, path, params, headers, files, url_override, api_version)
#     334
#     335         if fb_response.is_failure():
# --> 336             raise fb_response.error()
#     337
#     338         self._num_requests_succeeded += 1
#
# FacebookRequestError:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v3.2/act_2039741129633793/adcreatives
#   Params:  {'level': 'ad', 'fields': 'image_url,title,status,url_tags', 'summary': 'true'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#17) User request limit reached",
#         "type": "OAuthException",
#         "is_transient": true,
#         "code": 17,
#         "error_subcode": 2446079,
#         "fbtrace_id": "FUY44Tt5qwH"
#       }
#     }

# %%
for creative in creatives:
    print(creative)
# Out:
# ---------------------------------------------------------------------------
# FacebookRequestError                      Traceback (most recent call last)
# <ipython-input-105-688272fe01c3> in <module>()
# ----> 1 for creative in creatives:
#       2     print(creative)
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in __next__(self)
#     772         # Load next page at end.
#     773         # If load_next_page returns False, raise StopIteration exception
# --> 774         if not self._queue and not self.load_next_page():
#     775             raise StopIteration()
#     776
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in load_next_page(self)
#     824             'GET',
#     825             self._path,
# --> 826             params=self.params,
#     827         ).json()
#     828
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in call(self, method, path, params, headers, files, url_override, api_version)
#     334
#     335         if fb_response.is_failure():
# --> 336             raise fb_response.error()
#     337
#     338         self._num_requests_succeeded += 1
#
# FacebookRequestError:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v3.2/act_2039741129633793/adcreatives?access_token=EAAgZAynXf8wsBAECSf1NPj4ZAajFgeagcXWj5cZAa82MkOIGFOqzNe4pkhX5ZCzhBeNwO2gU32qvOamvu1QXCeCjWnIKoXb2ry9guneMZB49789ZBPSClGcRlZBZASmIJfRKYHtV7VGJygUS5sowDOGzP2n25OW94dUZD&fields=image_url%2Ctitle%2Cstatus&summary=true&limit=25&after=MjM4NDMxMjA3ODkwMTA0ODMZD
#   Params:  {'level': 'ad', 'fields': 'image_url,title,status', 'summary': 'true'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#17) User request limit reached",
#         "type": "OAuthException",
#         "is_transient": true,
#         "code": 17,
#         "error_subcode": 2446079,
#         "fbtrace_id": "G/VdWrFsPyi"
#       }
#     }

# %%
ads = account.get_ads(fields=[
    'targeting'
], params={
    'level': 'ad',
    # 'time_range': {'since' : '2017-11-07','until': '2017-11-08'},
})

# %%
for ad in ads:
    print(ad)
# Out:
# <Ad> {
#     "id": "23843215042290483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 18,
#         "audience_network_positions": [
#             "instream_video"
#         ],
#         "custom_audiences": [
#             {
#                 "id": "23843214903300483",
#                 "name": "Web Visit 180 day  - w/o Purchase in Last 30"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "suggested_video",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003172273055",
#                         "name": "Sustainability"
#                     },
#                     {
#                         "id": "6003288328927",
#                         "name": "Ethical consumerism"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "messenger_positions": [
#             "messenger_home"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "audience_network",
#             "messenger"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236712570483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 30,
#         "custom_audiences": [
#             {
#                 "id": "23843236615620483",
#                 "name": "Add To Cart - Last 90"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237204550483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843040243490483",
#                 "name": "Lookalike (GB, 1%) - 2nd_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040243510483",
#                 "name": "Lookalike (GB, 1%) - 1st_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040244350483",
#                 "name": "Lookalike (GB, 1%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "GB"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237184780483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843202239510483",
#                 "name": "Lookalike (AU, 10%) - Purchase 180 Days"
#             },
#             {
#                 "id": "23843218912210483",
#                 "name": "Lookalike (AU, 5%) - Rewards List"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237201710483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843040242680483",
#                 "name": "Lookalike (CA, 1%) - 2nd_KS_subscribed_members"
#             },
#             {
#                 "id": "23843202238880483",
#                 "name": "Lookalike (CA, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237178770483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843040242680483",
#                 "name": "Lookalike (CA, 1%) - 2nd_KS_subscribed_members"
#             },
#             {
#                 "id": "23843202238880483",
#                 "name": "Lookalike (CA, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237204520483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23842937475150483",
#                 "name": "Lookalike (AU, NZ, 6%) - LEZE The Label - Kickstarter Customer Audience - July 28"
#             },
#             {
#                 "id": "23843202239510483",
#                 "name": "Lookalike (AU, 10%) - Purchase 180 Days"
#             },
#             {
#                 "id": "23843218912210483",
#                 "name": "Lookalike (AU, 5%) - Rewards List"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237204540483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843202238620483",
#                 "name": "Lookalike (US, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236958900483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843202238620483",
#                 "name": "Lookalike (US, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237092640483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843202238620483",
#                 "name": "Lookalike (US, 10%) - Purchase 180 Days"
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         }
#     }
# }
# <Ad> {
#     "id": "23843237184770483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23842937303280483",
#                 "name": "Lookalike (US, 1% to 2%) - LEZE The Label - Kickstarter Customer Audience - July 28"
#             },
#             {
#                 "id": "23843202238620483",
#                 "name": "Lookalike (US, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237184790483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843040243490483",
#                 "name": "Lookalike (GB, 1%) - 2nd_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040243510483",
#                 "name": "Lookalike (GB, 1%) - 1st_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040244350483",
#                 "name": "Lookalike (GB, 1%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "GB"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237092650483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843040243490483",
#                 "name": "Lookalike (GB, 1%) - 2nd_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040243510483",
#                 "name": "Lookalike (GB, 1%) - 1st_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040244350483",
#                 "name": "Lookalike (GB, 1%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "GB"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843237092680483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23842937475150483",
#                 "name": "Lookalike (AU, NZ, 6%) - LEZE The Label - Kickstarter Customer Audience - July 28"
#             },
#             {
#                 "id": "23843202239510483",
#                 "name": "Lookalike (AU, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "NZ",
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236958880483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843202239510483",
#                 "name": "Lookalike (AU, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236958910483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843040243490483",
#                 "name": "Lookalike (GB, 1%) - 2nd_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040243510483",
#                 "name": "Lookalike (GB, 1%) - 1st_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040244350483",
#                 "name": "Lookalike (GB, 1%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "GB"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236939490483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843202238880483",
#                 "name": "Lookalike (CA, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236900920483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843202238880483",
#                 "name": "Lookalike (CA, 10%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "instream_video",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236612270483",
#     "targeting": {
#         "age_max": 50,
#         "age_min": 30,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "suggested_video"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003350444639",
#                         "name": "J.Crew"
#                     }
#                 ]
#             },
#             {
#                 "behaviors": [
#                     {
#                         "id": "6071631541183",
#                         "name": "Engaged Shoppers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843215180430483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "audience_network_positions": [
#             "classic",
#             "rewarded_video"
#         ],
#         "custom_audiences": [
#             {
#                 "id": "23843215056260483",
#                 "name": "Lookalike (CA, US, 1%) - LEZE The Label - Kickstarter Customer Audience  - Value Based - July 28"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003172273055",
#                         "name": "Sustainability"
#                     },
#                     {
#                         "id": "6003288328927",
#                         "name": "Ethical consumerism"
#                     },
#                     {
#                         "id": "6003641846820",
#                         "name": "Veganism"
#                     },
#                     {
#                         "id": "6015642401201",
#                         "name": "tentree"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook",
#             "audience_network"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843215042280483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 18,
#         "audience_network_positions": [
#             "instream_video"
#         ],
#         "custom_audiences": [
#             {
#                 "id": "23843214903300483",
#                 "name": "Web Visit 180 day  - w/o Purchase in Last 30"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "suggested_video",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003172273055",
#                         "name": "Sustainability"
#                     },
#                     {
#                         "id": "6003288328927",
#                         "name": "Ethical consumerism"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "messenger_positions": [
#             "messenger_home"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "audience_network",
#             "messenger"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843215185740483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "audience_network_positions": [
#             "classic",
#             "rewarded_video"
#         ],
#         "custom_audiences": [
#             {
#                 "id": "23843215056260483",
#                 "name": "Lookalike (CA, US, 1%) - LEZE The Label - Kickstarter Customer Audience  - Value Based - July 28"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003172273055",
#                         "name": "Sustainability"
#                     },
#                     {
#                         "id": "6003288328927",
#                         "name": "Ethical consumerism"
#                     },
#                     {
#                         "id": "6003641846820",
#                         "name": "Veganism"
#                     },
#                     {
#                         "id": "6015642401201",
#                         "name": "tentree"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook",
#             "audience_network"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843215045390483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 18,
#         "audience_network_positions": [
#             "instream_video"
#         ],
#         "custom_audiences": [
#             {
#                 "id": "23843214903300483",
#                 "name": "Web Visit 180 day  - w/o Purchase in Last 30"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "suggested_video",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003172273055",
#                         "name": "Sustainability"
#                     },
#                     {
#                         "id": "6003288328927",
#                         "name": "Ethical consumerism"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "messenger_positions": [
#             "messenger_home"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "audience_network",
#             "messenger"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236649710483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 30,
#         "custom_audiences": [
#             {
#                 "id": "23843236615620483",
#                 "name": "Add To Cart - Last 90"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ],
#         "targeting_optimization": "expansion_all"
#     }
# }
# <Ad> {
#     "id": "23843215183070483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "audience_network_positions": [
#             "classic",
#             "rewarded_video"
#         ],
#         "custom_audiences": [
#             {
#                 "id": "23843202229930483",
#                 "name": "Lookalike (US, 1%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003172273055",
#                         "name": "Sustainability"
#                     },
#                     {
#                         "id": "6003288328927",
#                         "name": "Ethical consumerism"
#                     },
#                     {
#                         "id": "6003641846820",
#                         "name": "Veganism"
#                     },
#                     {
#                         "id": "6015642401201",
#                         "name": "tentree"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook",
#             "audience_network"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843215180440483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "audience_network_positions": [
#             "classic",
#             "rewarded_video"
#         ],
#         "custom_audiences": [
#             {
#                 "id": "23843202229930483",
#                 "name": "Lookalike (US, 1%) - Purchase 180 Days"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003172273055",
#                         "name": "Sustainability"
#                     },
#                     {
#                         "id": "6003288328927",
#                         "name": "Ethical consumerism"
#                     },
#                     {
#                         "id": "6003641846820",
#                         "name": "Veganism"
#                     },
#                     {
#                         "id": "6015642401201",
#                         "name": "tentree"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook",
#             "audience_network"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843215049630483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 18,
#         "audience_network_positions": [
#             "instream_video"
#         ],
#         "custom_audiences": [
#             {
#                 "id": "23843214903300483",
#                 "name": "Web Visit 180 day  - w/o Purchase in Last 30"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "suggested_video",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003172273055",
#                         "name": "Sustainability"
#                     },
#                     {
#                         "id": "6003288328927",
#                         "name": "Ethical consumerism"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "messenger_positions": [
#             "messenger_home"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "audience_network",
#             "messenger"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843218748670483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 25,
#         "custom_audiences": [
#             {
#                 "id": "23842912550740483",
#                 "name": "Lookalike (CA, 1%) - People who like LEZ\u00c9 the Label"
#             },
#             {
#                 "id": "23843024519130483",
#                 "name": "Lookalike (CAD, 1%) Paying shopify customers"
#             },
#             {
#                 "id": "23843040240630483",
#                 "name": "Lookalike (CA, 1%) - 1st_KS_subscribed_members"
#             },
#             {
#                 "id": "23843040242680483",
#                 "name": "Lookalike (CA, 1%) - 2nd_KS_subscribed_members"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ],
#         "targeting_optimization": "none"
#     }
# }
# <Ad> {
#     "id": "23843236768820483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843187623130483",
#                 "name": "Add to Cart 180"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236768840483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843187623130483",
#                 "name": "Add to Cart 180"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236768830483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843187623130483",
#                 "name": "Add to Cart 180"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "GB"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843232119230483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843187623130483",
#                 "name": "Add to Cart 180"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ],
#         "targeting_optimization": "expansion_all"
#     }
# }
# <Ad> {
#     "id": "23843236763590483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 30,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "story"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003350444639",
#                         "name": "J.Crew"
#                     }
#                 ]
#             },
#             {
#                 "behaviors": [
#                     {
#                         "id": "6071631541183",
#                         "name": "Engaged Shoppers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236762960483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 30,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "story"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003350444639",
#                         "name": "J.Crew"
#                     }
#                 ]
#             },
#             {
#                 "behaviors": [
#                     {
#                         "id": "6071631541183",
#                         "name": "Engaged Shoppers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "CA"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236763620483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 30,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "story"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003350444639",
#                         "name": "J.Crew"
#                     }
#                 ]
#             },
#             {
#                 "behaviors": [
#                     {
#                         "id": "6071631541183",
#                         "name": "Engaged Shoppers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "GB"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236763580483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 30,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "suggested_video",
#             "story"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003350444639",
#                         "name": "J.Crew"
#                     }
#                 ]
#             },
#             {
#                 "behaviors": [
#                     {
#                         "id": "6071631541183",
#                         "name": "Engaged Shoppers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236762920483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 30,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "story"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003350444639",
#                         "name": "J.Crew"
#                     }
#                 ]
#             },
#             {
#                 "behaviors": [
#                     {
#                         "id": "6071631541183",
#                         "name": "Engaged Shoppers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "GB"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236762930483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 30,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "suggested_video",
#             "story"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003350444639",
#                         "name": "J.Crew"
#                     }
#                 ]
#             },
#             {
#                 "behaviors": [
#                     {
#                         "id": "6071631541183",
#                         "name": "Engaged Shoppers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843236602990483",
#     "targeting": {
#         "age_max": 50,
#         "age_min": 30,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "right_hand_column",
#             "suggested_video"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003350444639",
#                         "name": "J.Crew"
#                     }
#                 ]
#             },
#             {
#                 "behaviors": [
#                     {
#                         "id": "6071631541183",
#                         "name": "Engaged Shoppers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843235042820483",
#     "targeting": {
#         "age_max": 54,
#         "age_min": 44,
#         "custom_audiences": [
#             {
#                 "id": "23843040244350483",
#                 "name": "Lookalike (GB, 1%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "suggested_video",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "GB"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "facebook"
#         ],
#         "targeting_optimization": "expansion_all"
#     }
# }
# <Ad> {
#     "id": "23843068206510483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843040234510483",
#                 "name": "Lookalike (US, 1%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ],
#         "targeting_optimization": "none"
#     }
# }
# <Ad> {
#     "id": "23843041829080483",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 18,
#         "custom_audiences": [
#             {
#                 "id": "23843040234510483",
#                 "name": "Lookalike (US, 1%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ],
#         "targeting_optimization": "none"
#     }
# }
# <Ad> {
#     "id": "23843235027560483",
#     "targeting": {
#         "age_max": 54,
#         "age_min": 44,
#         "custom_audiences": [
#             {
#                 "id": "23843040237270483",
#                 "name": "Lookalike (AU, 5%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "suggested_video",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "AU"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook"
#         ],
#         "targeting_optimization": "expansion_all"
#     }
# }
# <Ad> {
#     "id": "23843234963290483",
#     "targeting": {
#         "age_max": 55,
#         "age_min": 45,
#         "custom_audiences": [
#             {
#                 "id": "23843040234510483",
#                 "name": "Lookalike (US, 1%) - paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "facebook"
#         ],
#         "targeting_optimization": "expansion_all"
#     }
# }
# <Ad> {
#     "id": "23843234999860483",
#     "targeting": {
#         "age_max": 54,
#         "age_min": 44,
#         "custom_audiences": [
#             {
#                 "id": "23843024519130483",
#                 "name": "Lookalike (CAD, 1%) Paying shopify customers"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed",
#             "story"
#         ],
#         "genders": [
#             2
#         ],
# ...
#                         "name": "Anthropologie"
#                     },
#                     {
#                         "id": "6003477456344",
#                         "name": "Ministry of Supply"
#                     },
#                     {
#                         "id": "6003499323365",
#                         "name": "Free People"
#                     },
#                     {
#                         "id": "6014327517318",
#                         "name": "Everlane"
#                     },
#                     {
#                         "id": "944402065590766",
#                         "name": "Kit and Ace"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "NZ",
#                 "CA",
#                 "AU"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843021444170483",
#     "targeting": {
#         "age_max": 44,
#         "age_min": 21,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23842935557500483",
#                 "name": "All Website Visitors - 120 Days"
#             },
#             {
#                 "id": "23842963106600483",
#                 "name": "Purchasers - 30 Days"
#             }
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003013562293",
#                         "name": "Reformation"
#                     },
#                     {
#                         "id": "6003122356122",
#                         "name": "Anthropologie"
#                     },
#                     {
#                         "id": "6003477456344",
#                         "name": "Ministry of Supply"
#                     },
#                     {
#                         "id": "6003499323365",
#                         "name": "Free People"
#                     },
#                     {
#                         "id": "6014327517318",
#                         "name": "Everlane"
#                     },
#                     {
#                         "id": "944402065590766",
#                         "name": "Kit and Ace"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843021444130483",
#     "targeting": {
#         "age_max": 44,
#         "age_min": 21,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23842935557500483",
#                 "name": "All Website Visitors - 120 Days"
#             },
#             {
#                 "id": "23842963106600483",
#                 "name": "Purchasers - 30 Days"
#             }
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003013562293",
#                         "name": "Reformation"
#                     },
#                     {
#                         "id": "6003122356122",
#                         "name": "Anthropologie"
#                     },
#                     {
#                         "id": "6003477456344",
#                         "name": "Ministry of Supply"
#                     },
#                     {
#                         "id": "6003499323365",
#                         "name": "Free People"
#                     },
#                     {
#                         "id": "6014327517318",
#                         "name": "Everlane"
#                     },
#                     {
#                         "id": "944402065590766",
#                         "name": "Kit and Ace"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843021444120483",
#     "targeting": {
#         "age_max": 44,
#         "age_min": 21,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23842935557500483",
#                 "name": "All Website Visitors - 120 Days"
#             },
#             {
#                 "id": "23842963106600483",
#                 "name": "Purchasers - 30 Days"
#             }
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003013562293",
#                         "name": "Reformation"
#                     },
#                     {
#                         "id": "6003122356122",
#                         "name": "Anthropologie"
#                     },
#                     {
#                         "id": "6003477456344",
#                         "name": "Ministry of Supply"
#                     },
#                     {
#                         "id": "6003499323365",
#                         "name": "Free People"
#                     },
#                     {
#                         "id": "6014327517318",
#                         "name": "Everlane"
#                     },
#                     {
#                         "id": "944402065590766",
#                         "name": "Kit and Ace"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843021439270483",
#     "targeting": {
#         "age_max": 44,
#         "age_min": 21,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23842935557500483",
#                 "name": "All Website Visitors - 120 Days"
#             },
#             {
#                 "id": "23842963106600483",
#                 "name": "Purchasers - 30 Days"
#             }
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003013562293",
#                         "name": "Reformation"
#                     },
#                     {
#                         "id": "6003122356122",
#                         "name": "Anthropologie"
#                     },
#                     {
#                         "id": "6003477456344",
#                         "name": "Ministry of Supply"
#                     },
#                     {
#                         "id": "6003499323365",
#                         "name": "Free People"
#                     },
#                     {
#                         "id": "6014327517318",
#                         "name": "Everlane"
#                     },
#                     {
#                         "id": "944402065590766",
#                         "name": "Kit and Ace"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "US"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23842983846970483",
#     "targeting": {
#         "age_max": 44,
#         "age_min": 21,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23842935557500483",
#                 "name": "All Website Visitors - 120 Days"
#             },
#             {
#                 "id": "23842963106600483",
#                 "name": "Purchasers - 30 Days"
#             }
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003013562293",
#                         "name": "Reformation"
#                     },
#                     {
#                         "id": "6003122356122",
#                         "name": "Anthropologie"
#                     },
#                     {
#                         "id": "6003477456344",
#                         "name": "Ministry of Supply"
#                     },
#                     {
#                         "id": "6003499323365",
#                         "name": "Free People"
#                     },
#                     {
#                         "id": "6014327517318",
#                         "name": "Everlane"
#                     },
#                     {
#                         "id": "944402065590766",
#                         "name": "Kit and Ace"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "NZ",
#                 "CA",
#                 "AU"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "instagram"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843021421740483",
#     "targeting": {
#         "age_max": 44,
#         "age_min": 21,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23842935557500483",
#                 "name": "All Website Visitors - 120 Days"
#             },
#             {
#                 "id": "23842963106600483",
#                 "name": "Purchasers - 30 Days"
#             }
#         ],
#         "facebook_positions": [
#             "feed",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003013562293",
#                         "name": "Reformation"
#                     },
#                     {
#                         "id": "6003122356122",
#                         "name": "Anthropologie"
#                     },
#                     {
#                         "id": "6003477456344",
#                         "name": "Ministry of Supply"
#                     },
#                     {
#                         "id": "6003499323365",
#                         "name": "Free People"
#                     },
#                     {
#                         "id": "6014327517318",
#                         "name": "Everlane"
#                     },
#                     {
#                         "id": "944402065590766",
#                         "name": "Kit and Ace"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "NZ",
#                 "CA",
#                 "AU"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "facebook"
#         ]
#     }
# }
# <Ad> {
#     "id": "23843021421770483",
#     "targeting": {
#         "age_max": 44,
#         "age_min": 21,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23842935557500483",
#                 "name": "All Website Visitors - 120 Days"
#             },
#             {
#                 "id": "23842963106600483",
#                 "name": "Purchasers - 30 Days"
#             }
#         ],
#         "facebook_positions": [
#             "feed",
#             "marketplace"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003013562293",
#                         "name": "Reformation"
#                     },
#                     {
#                         "id": "6003122356122",
#                         "name": "Anthropologie"
#                     },
#                     {
#                         "id": "6003477456344",
#                         "name": "Ministry of Supply"
#                     },
#                     {
#                         "id": "6003499323365",
#                         "name": "Free People"
#                     },
#                     {
#                         "id": "6014327517318",
#                         "name": "Everlane"
#                     },
#                     {
#                         "id": "944402065590766",
#                         "name": "Kit and Ace"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "NZ",
#                 "CA",
#                 "AU"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "locales": [
#             24,
#             6
#         ],
#         "publisher_platforms": [
#             "facebook"
#         ]
#     }
# }
# ---------------------------------------------------------------------------
# FacebookRequestError                      Traceback (most recent call last)
# <ipython-input-108-76bfca9a6930> in <module>()
# ----> 1 for ad in ads:
#       2     print(ad)
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in __next__(self)
#     772         # Load next page at end.
#     773         # If load_next_page returns False, raise StopIteration exception
# --> 774         if not self._queue and not self.load_next_page():
#     775             raise StopIteration()
#     776
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in load_next_page(self)
#     824             'GET',
#     825             self._path,
# --> 826             params=self.params,
#     827         ).json()
#     828
#
# ~/Envs/growth/lib/python3.6/site-packages/facebook_business/api.py in call(self, method, path, params, headers, files, url_override, api_version)
#     334
#     335         if fb_response.is_failure():
# --> 336             raise fb_response.error()
#     337
#     338         self._num_requests_succeeded += 1
#
# FacebookRequestError:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v3.2/act_2039741129633793/ads?access_token=EAAgZAynXf8wsBAECSf1NPj4ZAajFgeagcXWj5cZAa82MkOIGFOqzNe4pkhX5ZCzhBeNwO2gU32qvOamvu1QXCeCjWnIKoXb2ry9guneMZB49789ZBPSClGcRlZBZASmIJfRKYHtV7VGJygUS5sowDOGzP2n25OW94dUZD&fields=targeting&summary=true&limit=25&after=MjM4NDMwMjE0MjE3NzA0ODMZD
#   Params:  {'level': 'ad', 'fields': 'targeting', 'summary': 'true'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#17) User request limit reached",
#         "type": "OAuthException",
#         "is_transient": true,
#         "code": 17,
#         "error_subcode": 2446079,
#         "fbtrace_id": "CdU7Mp5sMaf"
#       }
#     }
